# %%
import pandas as pd

# %%
df = pd.read_csv('Phishing emails\Phishing_Email.csv').drop(columns=['Unnamed: 0'])
df
# Out:
#                                               Email Text      Email Type
# 0      re : 6 . 1100 , disc : uniformitarianism , re ...      Safe Email
# 1      the other side of * galicismos * * galicismo *...      Safe Email
# 2      re : equistar deal tickets are you still avail...      Safe Email
# 3      \nHello I am your hot lil horny toy.\n    I am...  Phishing Email
# 4      software at incredibly low prices ( 86 % lower...  Phishing Email
# ...                                                  ...             ...
# 18645  date a lonely housewife always wanted to date ...  Phishing Email
# 18646  request submitted : access request for anita ....      Safe Email
# 18647  re : important - prc mtg hi dorn & john , as y...      Safe Email
# 18648  press clippings - letter on californian utilit...      Safe Email
# 18649                                              empty  Phishing Email
#
# [18650 rows x 2 columns]

# %%
df['Email Type'].value_counts()
# Out:
# Email Type
# Safe Email        11322
# Phishing Email     7328
# Name: count, dtype: int64

# %%
df['Email Text'].isna().sum()
# Out:
# 16

# %%
 df['Email Text'].value_counts().reset_index(name="count").query("count > 3")
# Out:
#                                            Email Text  count
# 0                                               empty    533
# 1   calpine daily gas nomination > ricky a . arche...      9
# 2   \nÂ \nDear \n              Homeowner,Â        ...      8
# 3   creditfixThank You,Your email address was obta...      7
# 4   \nHello I am your hot lil horny toy.\n    I am...      7
# 5   \nIf you are struggling with MS Access to mana...      5
# 6    A man endowed with a 7-8" hammer is simply\n ...      5
# 7   New Web Technology\nUNLIMITED WEB CONFERENCING...      4
# 8   URL: http://www.askbjoernhansen.com/archives/2...      4
# 9   h e l l od e a rh o m eo w n e r , w eh a v eb...      4
# 10  URL: http://www.askbjoernhansen.com/archives/2...      4
# 11  \nÂ You can't predict the future, but you can ...      4
# 12  Digital Publishing Tools - Free Software Alert...      4
# 13  As seen on NBC, CBS, CNN, and even Oprah! The ...      4
# ...
